# %%
import streamlit as st
import numpy as np
import pandas as pd
import plotly.express as px
import fastf1
import os
from fastf1 import plotting
from matplotlib import pyplot as plt
fastf1.Cache.enable_cache('fastf1_cache')  # optional but recommended
results_path = os.path.join(os.getcwd(), "results_cache")

# %%
session = fastf1.get_session(2019, 'Monza', 'Q')
session.load()
# Out:
# 2022-09-27 15:51:42.167 INFO    root: Loading data for Italian Grand Prix - Qualifying [v2.3.0]
# 2022-09-27 15:51:42.169 INFO    root: Using cached data for driver_info
# 2022-09-27 15:51:42.231 INFO    root: Using cached data for timing_data
# 2022-09-27 15:51:42.233 INFO    root: Using cached data for timing_app_data
# 2022-09-27 15:51:42.234 INFO    root: Processing timing data...
# 2022-09-27 15:51:42.246 INFO    root: Using cached data for session_status_data
# 2022-09-27 15:51:42.250 INFO    root: Using cached data for track_status_data
# c:\Users\piuscarbon\.conda\envs\F1\lib\site-packages\fastf1\core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# ...

# %%
fast_leclerc = session.laps.pick_driver('LEC').pick_fastest()
lec_pos_data = fast_leclerc.get_pos_data()

fast_ham = session.laps.pick_driver('HAM').pick_fastest()
ham_pos_data = fast_ham.get_pos_data()
# Out:
# c:\Users\piuscarbon\.conda\envs\F1\lib\site-packages\fastf1\core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time

# %%
ham_pos_data
# Out:
#                        Date   Status     X     Y     Z Source  \
# 0   2019-09-07 13:55:00.969  OnTrack -1392  -729  1872    pos
# 1   2019-09-07 13:55:01.269  OnTrack -1368  -481  1874    pos
# 2   2019-09-07 13:55:01.569  OnTrack -1342  -222  1875    pos
# 3   2019-09-07 13:55:01.869  OnTrack -1317    36  1876    pos
# 4   2019-09-07 13:55:02.169  OnTrack -1293   275  1878    pos
# ..                      ...      ...   ...   ...   ...    ...
# 262 2019-09-07 13:56:18.870  OnTrack -1477 -1960  1867    pos
# 263 2019-09-07 13:56:19.170  OnTrack -1470 -1721  1868    pos
# 264 2019-09-07 13:56:19.470  OnTrack -1457 -1481  1869    pos
# 265 2019-09-07 13:56:19.770  OnTrack -1435 -1172  1870    pos
# 266 2019-09-07 13:56:20.070  OnTrack -1407  -879  1871    pos
#
#                       Time            SessionTime
# 0   0 days 00:00:00.226000 0 days 01:09:59.876000
# 1   0 days 00:00:00.526000 0 days 01:10:00.176000
# 2   0 days 00:00:00.826000 0 days 01:10:00.476000
# ...

# %%
lec_pos_data
# Out:
#                        Date   Status     X     Y     Z Source  \
# 0   2019-09-07 13:54:56.770  OnTrack -1398  -789  1872    pos
# 1   2019-09-07 13:54:57.070  OnTrack -1372  -530  1873    pos
# 2   2019-09-07 13:54:57.369  OnTrack -1347  -272  1874    pos
# 3   2019-09-07 13:54:57.669  OnTrack -1322   -23  1876    pos
# 4   2019-09-07 13:54:57.969  OnTrack -1297   235  1877    pos
# ..                      ...      ...   ...   ...   ...    ...
# 262 2019-09-07 13:56:14.671  OnTrack -1479 -2090  1866    pos
# 263 2019-09-07 13:56:14.971  OnTrack -1475 -1850  1868    pos
# 264 2019-09-07 13:56:15.271  OnTrack -1465 -1621  1869    pos
# 265 2019-09-07 13:56:15.571  OnTrack -1449 -1351  1870    pos
# 266 2019-09-07 13:56:15.871  OnTrack -1422 -1032  1871    pos
#
#                       Time            SessionTime
# 0   0 days 00:00:00.116000 0 days 01:09:55.677000
# 1   0 days 00:00:00.416000 0 days 01:09:55.977000
# 2   0 days 00:00:00.715000 0 days 01:09:56.276000
# ...

# %%
def update(t):
    plt.scatter(lec_pos_data["X"], lec_pos_data["Y"], color="black")
    plt.scatter(lec_pos_data["X"][t], lec_pos_data["Y"][t])
    plt.scatter(ham_pos_data["X"][t], ham_pos_data["Y"][t])
    return

# %%
import matplotlib
ani = matplotlib.animation.FuncAnimation(fig, update, frames=min(len(lec_pos_data), len(ham_pos_data)), repeat=False)   
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 2
#       1 import matplotlib
# ----> 2 ani = matplotlib.animation.FuncAnimation(fig, update, frames=min(len(lec_pos_data), len(ham_pos_data)), repeat=False)
#       3 plt.show()
#
# File c:\Users\piuscarbon\.conda\envs\F1\lib\site-packages\matplotlib\_api\__init__.py:224, in caching_module_getattr.<locals>.__getattr__(name)
#     222 if name in props:
#     223     return props[name].__get__(instance)
# --> 224 raise AttributeError(
#     225     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'animation'
